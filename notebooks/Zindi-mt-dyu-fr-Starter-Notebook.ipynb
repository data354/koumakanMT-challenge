# %% [markdown]
# # Starter notebook
#
# The purpose of this Notebook is to build baseline model that translate dyula (dyu) language (source language) into French (fr) language (target language). we'll train from scratch a Transformer model using JoeyNMT.

# %% [markdown]
# NB: Run time execution of this notebook it less than **1h** respect resources (GPU, RAM) define below.
#
# For more details about JoeyNMT see [here](https://github.com/joeynmt)

# %% [markdown]
# ## Environmental setup
#
# > ⚠ **Important:** Before you start, set runtime type to GPU.

# %%
# !nvidia-smi
# Out:
# Thu Mar 28 11:28:27 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# <h2> If need it, you can create the Secret in Google Colab</h1>
#
# 1. Open your Google Colab notebook and click on the `secrets` tab.
# 2. Create a new secret with the name `EARTHENGINE_TOKEN`.
# 3. Paste the content from the clipboard into the `Value` input box of the created secret.
# 4. Toggle the button on the left to allow notebook access to the secret.
#
# ![](https://i.imgur.com/Z9R08uU.png)

# %%
import torch
torch.__version__
# Out:
# '2.2.1+cu121'

# %% [markdown]
# Mount your Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install joeynmt==2.3.0
# !pip install datasets==2.18.0

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Download
#
# We download the corpus train-dev-test subsets from Huggingface hub.

# %%
from datasets import load_dataset, DatasetDict, Translation
repo_name = "data354/Koumankan_mt_dyu_fr"
dataset = load_dataset(repo_name)
dataset
# Out:
# Downloading readme:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/530k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/102k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/55.8k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8065 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1471 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1393 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['ID', 'translation'],
#         num_rows: 8065
#     })
#     validation: Dataset({
#         features: ['ID', 'translation'],
#         num_rows: 1471
#     })
#     test: Dataset({
#         features: ['ID', 'translation'],
#         num_rows: 1393
#     })
# })

# %%
import re

## Data preprocessing

# Optional: lower case the corpora - this will make it easier to generalize, but without proper casing.
# Optional: remove punctuation.

src_lang = 'dyu'
trg_lang = "fr"
chars_to_remove_regex = '[!"&\(\),-./:;=?+.\n\[\]]'
def remove_special_characters(text):
    text = re.sub(chars_to_remove_regex, ' ', text.lower())
    return text.strip()

def clean_text(batch):
    # process source text
    batch['translation'][src_lang] = remove_special_characters(batch['translation'][src_lang])
    # process target text
    batch['translation'][trg_lang] = remove_special_characters(batch['translation'][trg_lang])

    return batch


dataset = dataset.map(clean_text)
dataset
# Out:
# Map:   0%|          | 0/8065 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1471 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1393 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['ID', 'translation'],
#         num_rows: 8065
#     })
#     validation: Dataset({
#         features: ['ID', 'translation'],
#         num_rows: 1471
#     })
#     test: Dataset({
#         features: ['ID', 'translation'],
#         num_rows: 1393
#     })
# })

# %% [markdown]
# Let's inspect the sentences.

# %%
dataset["validation"]["translation"][:3]
# Out:
# [{'dyu': 'i tɔgɔ bi cogodɔ', 'fr': 'tu portes un nom de fantaisie'},
#  {'dyu': 'puɛn saba fɔlɔ', 'fr': 'trois points d’avance'},
#  {'dyu': 'tile bena', 'fr': 'le soleil s’est couché'}]

# %% [markdown]
# Save the train-dev subsets on disk.

# %%
data_dir = "data/dyu_fr"
dataset.save_to_disk(data_dir)
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/8065 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1471 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/1393 [00:00<?, ? examples/s]

# %% [markdown]
# ### Vocabulary
#
# We will use the [sentencepiece](https://github.com/google/sentencepiece) library to split words into subwords (BPE) according to their frequency in the training corpus.
#
# `build_vocab.py` script will train the BPE model and creates joint vocabulary. It takes the same config file as the joeynmt.

# %%
from pathlib import Path

# model dir
model_dir = "models/dyu_fr"

# Create the config
config = """
name: "dyu_fr_transformer-sp"
joeynmt_version: "2.3.0"
model_dir: "{model_dir}"
use_cuda: True
fp16: False

data:
    train: "{data_dir}"
    dev: "{data_dir}"
    test: "{data_dir}"
    dataset_type: "huggingface"
    dataset_cfg:
        name: "dyu-fr"
    sample_dev_subset: 1460
    src:
        lang: "dyu"
        max_length: 100
        lowercase: False
        normalize: False
        level: "bpe"
        voc_limit: 4000
        voc_min_freq: 1
        voc_file: "{data_dir}/vocab.txt"
        tokenizer_type: "sentencepiece"
        tokenizer_cfg:
            model_file: "{data_dir}/sp.model"
    trg:
        lang: "fr"
        max_length: 100
        lowercase: False
        normalize: False
        level: "bpe"
        voc_limit: 4000
        voc_min_freq: 1
        voc_file: "{data_dir}/vocab.txt"
        tokenizer_type: "sentencepiece"
        tokenizer_cfg:
            model_file: "{data_dir}/sp.model"
    special_symbols:
        unk_token: "<unk>"
        unk_id: 0
        pad_token: "<pad>"
        pad_id: 1
        bos_token: "<s>"
        bos_id: 2
        eos_token: "</s>"
        eos_id: 3

""".format(data_dir=data_dir, model_dir=model_dir)
with (Path(data_dir) / "config.yaml").open('w') as f:
    f.write(config)

# %% [markdown]
# Call the `build_vocab.py` script with `--joint` flag to build the vocabulary

# %%
# !wget https://raw.githubusercontent.com/joeynmt/joeynmt/v2.3/scripts/build_vocab.py
! sudo chmod 777 build_vocab.py
# Out:
# --2024-03-28 11:48:26--  https://raw.githubusercontent.com/joeynmt/joeynmt/v2.3/scripts/build_vocab.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13170 (13K) [text/plain]
# Saving to: ‘build_vocab.py’
#
# build_vocab.py      100%[===================>]  12.86K  --.-KB/s    in 0s
#
# 2024-03-28 11:48:26 (73.7 MB/s) - ‘build_vocab.py’ saved [13170/13170]

# %%
# !python build_vocab.py {data_dir}/config.yaml --joint
# Out:
# 2024-03-28 11:48:31.515312: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-28 11:48:31.515401: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-28 11:48:31.632289: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-28 11:48:31.639749: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-28 11:48:32.663122: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Dropping NaN...: 100% 8065/8065 [00:00<00:00, 125570.97 examples/s]
# Preprocessing...: 100% 8065/8065 [00:00<00:00, 11393.50 examples/s]
# Filter: 100% 8065/8065 [00:00<00:00, 24323.57 examples/s]
# ### Training sentencepiece...
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/tmp/sentencepiece_19t73eg0.txt --model_prefix=data/dyu_fr/sp --model_type=unigram --vocab_size=4000 --character_coverage=1.0 --accept_language=dyu,fr --unk_piece=<unk> --bos_piece=<s> --eos_piece=</s> --pad_piece=<pad> --unk_id=0 --bos_id=2 --eos_id=3 --pad_id=1 --vocabulary_output_piece_score=false
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /tmp/sentencepiece_19t73eg0.txt
#   input_format:
#   model_prefix: data/dyu_fr/sp
#   model_type: UNIGRAM
#   vocab_size: 4000
#   accept_language: dyu
#   accept_language: fr
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 0
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 2
#   eos_id: 3
#   pad_id: 1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: /tmp/sentencepiece_19t73eg0.txt
# trainer_interface.cc(407) LOG(INFO) Loaded all 16130 sentences
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=470835
# trainer_interface.cc(558) LOG(INFO) Alphabet size=79
# trainer_interface.cc(559) LOG(INFO) Final character coverage=1
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 16130 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=251398
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 32786 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 16130
# trainer_interface.cc(608) LOG(INFO) Done! 16906
# unigram_model_trainer.cc(564) LOG(INFO) Using 16906 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=12806 obj=10.5164 num_tokens=32859 num_tokens/piece=2.56591
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=11184 obj=9.25634 num_tokens=33257 num_tokens/piece=2.97362
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=8381 obj=9.28154 num_tokens=35600 num_tokens/piece=4.2477
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=8359 obj=9.22704 num_tokens=35628 num_tokens/piece=4.26223
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=6268 obj=9.41457 num_tokens=39002 num_tokens/piece=6.2224
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=6268 obj=9.35124 num_tokens=39010 num_tokens/piece=6.22368
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=4701 obj=9.58835 num_tokens=42619 num_tokens/piece=9.06594
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=4701 obj=9.52127 num_tokens=42620 num_tokens/piece=9.06616
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=4400 obj=9.57065 num_tokens=43419 num_tokens/piece=9.86795
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=4400 obj=9.55719 num_tokens=43420 num_tokens/piece=9.86818
# trainer_interface.cc(686) LOG(INFO) Saving model: data/dyu_fr/sp.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: data/dyu_fr/sp.vocab
# ### Copying data/dyu_fr/sp.vocab to data/dyu_fr/vocab.txt ...
# ### Done.

# %% [markdown]
# The generated vocabulary looks like this:

# %%
# !head -10 {data_dir}/vocab.txt
# Out:
# <unk>
# <pad>
# <s>
# </s>
# ▁a
# s
# ▁ka
# '
# a
# ▁la

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Configuration
#
# Joey NMT reads model and training hyperparameters from a configuration file. We're generating this now to configure paths in the appropriate places.
#
# The configuration below builds a small Transformer model with shared embeddings between source and target language on the base of the subword vocabularies created above.

# %%
config += """
testing:
    #load_model: "{model_dir}/best.ckpt"
    n_best: 1
    beam_size: 5
    beam_alpha: 1.0
    batch_size: 256
    batch_type: "token"
    max_output_length: 100
    eval_metrics: ["bleu"]
    #return_prob: "hyp"
    #return_attention: False
    sacrebleu_cfg:
        tokenize: "13a"

training:
    #load_model: "{model_dir}/latest.ckpt"
    #reset_best_ckpt: False
    #reset_scheduler: False
    #reset_optimizer: False
    #reset_iter_state: False
    random_seed: 42
    optimizer: "adamw"
    normalization: "tokens"
    adam_betas: [0.9, 0.999]
    scheduling: "warmupinversesquareroot"
    learning_rate_warmup: 100
    learning_rate: 0.0003
    learning_rate_min: 0.00000001
    weight_decay: 0.0
    label_smoothing: 0.1
    loss: "crossentropy"
    batch_size: 512
    batch_type: "token"
    batch_multiplier: 4
    early_stopping_metric: "bleu"
    epochs: 30
    updates: 550
    validation_freq: 30
    logging_freq: 5
    overwrite: True
    shuffle: True
    print_valid_sents: [0, 1, 2, 3]
    keep_best_ckpts: 3

model:
    initializer: "xavier_uniform"
    bias_initializer: "zeros"
    init_gain: 1.0
    embed_initializer: "xavier_uniform"
    embed_init_gain: 1.0
    tied_embeddings: True
    tied_softmax: True
    encoder:
        type: "transformer"
        num_layers: 6
        num_heads: 4
        embeddings:
            embedding_dim: 256
            scale: True
            dropout: 0.0
        # typically ff_size = 4 x hidden_size
        hidden_size: 256
        ff_size: 1024
        dropout: 0.2
        layer_norm: "pre"
    decoder:
        type: "transformer"
        num_layers: 6
        num_heads: 8
        embeddings:
            embedding_dim: 256
            scale: True
            dropout: 0.0
        # typically ff_size = 4 x hidden_size
        hidden_size: 256
        ff_size: 1024
        dropout: 0.1
        layer_norm: "pre"

""".format(model_dir=model_dir)
with (Path(data_dir) / "config.yaml").open('w') as f:
    f.write(config)

# %% [markdown]
# ### Run training
# ⏳ The log reports the training process, look out for the prints of example translations and the BLEU evaluation scores to get an impression of the current quality.

# %%
# !python -m joeynmt train {data_dir}/config.yaml --skip-test
# Out:
# 2024-03-28 12:24:14.691991: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-28 12:24:14.692040: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-28 12:24:14.693416: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-28 12:24:14.700426: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-28 12:24:15.785040: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-28 12:24:17,620 - INFO - root - Hello! This is Joey-NMT (version 2.3.0).
# 2024-03-28 12:24:17,620 - INFO - joeynmt.config -                           cfg.name : dyu_fr_transformer-sp
# 2024-03-28 12:24:17,620 - INFO - joeynmt.config -                cfg.joeynmt_version : 2.3.0
# 2024-03-28 12:24:17,620 - INFO - joeynmt.config -                      cfg.model_dir : models/dyu_fr
# 2024-03-28 12:24:17,620 - INFO - joeynmt.config -                       cfg.use_cuda : True
# 2024-03-28 12:24:17,620 - INFO - joeynmt.config -                           cfg.fp16 : False
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -                     cfg.data.train : data/dyu_fr
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -                       cfg.data.dev : data/dyu_fr
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -                      cfg.data.test : data/dyu_fr
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -              cfg.data.dataset_type : huggingface
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -          cfg.data.dataset_cfg.name : dyu-fr
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -         cfg.data.sample_dev_subset : 1460
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -                  cfg.data.src.lang : dyu
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -            cfg.data.src.max_length : 100
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -             cfg.data.src.lowercase : False
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -             cfg.data.src.normalize : False
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -                 cfg.data.src.level : bpe
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -             cfg.data.src.voc_limit : 4000
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -          cfg.data.src.voc_min_freq : 1
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -              cfg.data.src.voc_file : data/dyu_fr/vocab.txt
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -        cfg.data.src.tokenizer_type : sentencepiece
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config - cfg.data.src.tokenizer_cfg.model_file : data/dyu_fr/sp.model
# 2024-03-28 12:24:17,621 - INFO - joeynmt.config -                  cfg.data.trg.lang : fr
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -            cfg.data.trg.max_length : 100
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -             cfg.data.trg.lowercase : False
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -             cfg.data.trg.normalize : False
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -                 cfg.data.trg.level : bpe
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -             cfg.data.trg.voc_limit : 4000
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -          cfg.data.trg.voc_min_freq : 1
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -              cfg.data.trg.voc_file : data/dyu_fr/vocab.txt
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -        cfg.data.trg.tokenizer_type : sentencepiece
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config - cfg.data.trg.tokenizer_cfg.model_file : data/dyu_fr/sp.model
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config - cfg.data.special_symbols.unk_token : <unk>
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -    cfg.data.special_symbols.unk_id : 0
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config - cfg.data.special_symbols.pad_token : <pad>
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -    cfg.data.special_symbols.pad_id : 1
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config - cfg.data.special_symbols.bos_token : <s>
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -    cfg.data.special_symbols.bos_id : 2
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config - cfg.data.special_symbols.eos_token : </s>
# 2024-03-28 12:24:17,622 - INFO - joeynmt.config -    cfg.data.special_symbols.eos_id : 3
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -                 cfg.testing.n_best : 1
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -              cfg.testing.beam_size : 5
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -             cfg.testing.beam_alpha : 1.0
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -             cfg.testing.batch_size : 256
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -             cfg.testing.batch_type : token
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -      cfg.testing.max_output_length : 100
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -           cfg.testing.eval_metrics : ['bleu']
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config - cfg.testing.sacrebleu_cfg.tokenize : 13a
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -           cfg.training.random_seed : 42
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -             cfg.training.optimizer : adamw
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -         cfg.training.normalization : tokens
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -            cfg.training.adam_betas : [0.9, 0.999]
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -            cfg.training.scheduling : warmupinversesquareroot
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -  cfg.training.learning_rate_warmup : 100
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -         cfg.training.learning_rate : 0.0003
# 2024-03-28 12:24:17,623 - INFO - joeynmt.config -     cfg.training.learning_rate_min : 1e-08
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -          cfg.training.weight_decay : 0.0
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -       cfg.training.label_smoothing : 0.1
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -                  cfg.training.loss : crossentropy
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -            cfg.training.batch_size : 512
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -            cfg.training.batch_type : token
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -      cfg.training.batch_multiplier : 4
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config - cfg.training.early_stopping_metric : bleu
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -                cfg.training.epochs : 30
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -               cfg.training.updates : 550
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -       cfg.training.validation_freq : 30
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -          cfg.training.logging_freq : 5
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -             cfg.training.overwrite : True
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -               cfg.training.shuffle : True
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -     cfg.training.print_valid_sents : [0, 1, 2, 3]
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -       cfg.training.keep_best_ckpts : 3
# 2024-03-28 12:24:17,624 - INFO - joeynmt.config -              cfg.model.initializer : xavier_uniform
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -         cfg.model.bias_initializer : zeros
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -                cfg.model.init_gain : 1.0
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -        cfg.model.embed_initializer : xavier_uniform
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -          cfg.model.embed_init_gain : 1.0
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -          cfg.model.tied_embeddings : True
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -             cfg.model.tied_softmax : True
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -             cfg.model.encoder.type : transformer
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -       cfg.model.encoder.num_layers : 6
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -        cfg.model.encoder.num_heads : 4
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config - cfg.model.encoder.embeddings.embedding_dim : 256
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config - cfg.model.encoder.embeddings.scale : True
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config - cfg.model.encoder.embeddings.dropout : 0.0
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -      cfg.model.encoder.hidden_size : 256
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -          cfg.model.encoder.ff_size : 1024
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -          cfg.model.encoder.dropout : 0.2
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -       cfg.model.encoder.layer_norm : pre
# 2024-03-28 12:24:17,625 - INFO - joeynmt.config -             cfg.model.decoder.type : transformer
# 2024-03-28 12:24:17,626 - INFO - joeynmt.config -       cfg.model.decoder.num_layers : 6
# 2024-03-28 12:24:17,626 - INFO - joeynmt.config -        cfg.model.decoder.num_heads : 8
# 2024-03-28 12:24:17,626 - INFO - joeynmt.config - cfg.model.decoder.embeddings.embedding_dim : 256
# 2024-03-28 12:24:17,626 - INFO - joeynmt.config - cfg.model.decoder.embeddings.scale : True
# 2024-03-28 12:24:17,626 - INFO - joeynmt.config - cfg.model.decoder.embeddings.dropout : 0.0
# 2024-03-28 12:24:17,626 - INFO - joeynmt.config -      cfg.model.decoder.hidden_size : 256
# 2024-03-28 12:24:17,626 - INFO - joeynmt.config -          cfg.model.decoder.ff_size : 1024
# 2024-03-28 12:24:17,626 - INFO - joeynmt.config -          cfg.model.decoder.dropout : 0.1
# 2024-03-28 12:24:17,626 - INFO - joeynmt.config -       cfg.model.decoder.layer_norm : pre
# 2024-03-28 12:24:17,662 - INFO - joeynmt.data - Building tokenizer...
# 2024-03-28 12:24:17,675 - INFO - joeynmt.tokenizers - dyu tokenizer: SentencePieceTokenizer(level=bpe, lowercase=False, normalize=False, filter_by_length=(-1, 100), pretokenizer=none, tokenizer=SentencePieceProcessor, nbest_size=5, alpha=0.0)
# 2024-03-28 12:24:17,675 - INFO - joeynmt.tokenizers - fr tokenizer: SentencePieceTokenizer(level=bpe, lowercase=False, normalize=False, filter_by_length=(-1, 100), pretokenizer=none, tokenizer=SentencePieceProcessor, nbest_size=5, alpha=0.0)
# 2024-03-28 12:24:17,675 - INFO - joeynmt.data - Loading train set...
# 2024-03-28 12:24:17,868 - INFO - datasets - PyTorch version 2.2.1+cu121 available.
# 2024-03-28 12:24:17,869 - INFO - datasets - TensorFlow version 2.15.0 available.
# 2024-03-28 12:24:17,870 - INFO - datasets - JAX version 0.4.23 available.
# 2024-03-28 12:24:18,023 - INFO - joeynmt.data - Building vocabulary...
# 2024-03-28 12:24:18,237 - INFO - joeynmt.data - Loading dev set...
# 2024-03-28 12:24:18,369 - INFO - joeynmt.data - Loading test set...
# 2024-03-28 12:24:18,516 - INFO - joeynmt.data - Data loaded.
# 2024-03-28 12:24:18,516 - INFO - joeynmt.data - Train dataset: HuggingfaceTranslationDataset(len=8065, src_lang="dyu", trg_lang="fr", has_trg=True, random_subset=-1, has_src_prompt=False, has_trg_prompt=False, name=dyu-fr, split=train)
# 2024-03-28 12:24:18,516 - INFO - joeynmt.data - Valid dataset: HuggingfaceTranslationDataset(len=1471, src_lang="dyu", trg_lang="fr", has_trg=True, random_subset=1460, has_src_prompt=False, has_trg_prompt=False, name=dyu-fr, split=validation)
# 2024-03-28 12:24:18,516 - INFO - joeynmt.data -  Test dataset: HuggingfaceTranslationDataset(len=1393, src_lang="dyu", trg_lang="fr", has_trg=True, random_subset=-1, has_src_prompt=False, has_trg_prompt=False, name=dyu-fr, split=test)
# 2024-03-28 12:24:18,517 - INFO - joeynmt.data - First training example:
# 	[SRC] ▁a ▁bi ▁ji ▁min ▁na
# 	[TRG] ▁il ▁bo it ▁de ▁l ’ eau
# 2024-03-28 12:24:18,517 - INFO - joeynmt.data - First 10 Src tokens: (0) <unk> (1) <pad> (2) <s> (3) </s> (4) ▁a (5) s (6) ▁ka (7) ' (8) a (9) ▁la
# 2024-03-28 12:24:18,517 - INFO - joeynmt.data - First 10 Trg tokens: (0) <unk> (1) <pad> (2) <s> (3) </s> (4) ▁a (5) s (6) ▁ka (7) ' (8) a (9) ▁la
# 2024-03-28 12:24:18,517 - INFO - joeynmt.data - Number of unique Src tokens (vocab_size): 4000
# 2024-03-28 12:24:18,518 - INFO - joeynmt.data - Number of unique Trg tokens (vocab_size): 4000
# 2024-03-28 12:24:18,521 - WARNING - joeynmt.tokenizers - /content/models/dyu_fr/sp.model already exists. Stop copying.
# 2024-03-28 12:24:18,522 - INFO - joeynmt.model - Building an encoder-decoder model...
# 2024-03-28 12:24:18,726 - INFO - joeynmt.model - Enc-dec model built.
# 2024-03-28 12:24:18,730 - INFO - joeynmt.model - Total params: 12084224
# 2024-03-28 12:24:18,955 - INFO - joeynmt.prediction - Model(
# 	encoder=TransformerEncoder(num_layers=6, num_heads=4, alpha=1.0, layer_norm="pre", activation=ReLU()),
# 	decoder=TransformerDecoder(num_layers=6, num_heads=8, alpha=1.0, layer_norm="pre", activation=ReLU()),
# 	src_embed=Embeddings(embedding_dim=256, vocab_size=4000),
# 	trg_embed=Embeddings(embedding_dim=256, vocab_size=4000),
# 	loss_function=XentLoss(criterion=KLDivLoss(), smoothing=0.1))
# 2024-03-28 12:24:19,756 - INFO - joeynmt.builders - AdamW(lr=0.0003, weight_decay=0.0, betas=[0.9, 0.999])
# 2024-03-28 12:24:19,756 - INFO - joeynmt.builders - WarmupInverseSquareRootScheduler(warmup=100, decay_rate=0.003000, peak_rate=0.0003, min_rate=1e-08)
# 2024-03-28 12:24:19,756 - INFO - joeynmt.training - Train config:
# 	device: cuda
# 	n_gpu: 1
# 	ddp training: False
# 	16-bits training: False
# 	gradient accumulation: 4
# 	batch size per device: 512
# 	effective batch size (w. parallel & accumulation): 2048
# 2024-03-28 12:24:19,757 - INFO - joeynmt.training - EPOCH 1
# 2024-03-28 12:24:21,791 - INFO - joeynmt.training - Epoch   1, Step:        5, Batch Loss:     6.873233, Batch Acc: 0.080781, Tokens per Sec:     1992, Lr: 0.000015
# 2024-03-28 12:24:23,203 - INFO - joeynmt.training - Epoch   1, Step:       10, Batch Loss:     6.828800, Batch Acc: 0.105026, Tokens per Sec:     2835, Lr: 0.000030
# 2024-03-28 12:24:24,404 - INFO - joeynmt.training - Epoch   1, Step:       15, Batch Loss:     6.714606, Batch Acc: 0.098434, Tokens per Sec:     3351, Lr: 0.000045
# 2024-03-28 12:24:25,378 - INFO - joeynmt.training - Epoch   1, Step:       20, Batch Loss:     6.608756, Batch Acc: 0.096645, Tokens per Sec:     4103, Lr: 0.000060
# 2024-03-28 12:24:26,360 - INFO - joeynmt.training - Epoch   1, Step:       25, Batch Loss:     6.517596, Batch Acc: 0.105980, Tokens per Sec:     4192, Lr: 0.000075
# 2024-03-28 12:24:27,336 - INFO - joeynmt.training - Epoch   1, Step:       30, Batch Loss:     6.449704, Batch Acc: 0.096631, Tokens per Sec:     4383, Lr: 0.000090
# 2024-03-28 12:24:27,337 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=72
# 2024-03-28 12:24:27,337 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [00:04<00:00, 333.64it/s]
# 2024-03-28 12:24:31,714 - INFO - joeynmt.prediction - Generation took 4.3765[sec].
# 2024-03-28 12:24:31,876 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:24:31,876 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.00, loss:   6.44, ppl: 623.62, acc:   0.09, 0.0673[sec]
# 2024-03-28 12:24:31,877 - INFO - joeynmt.training - Hooray! New best validation result [bleu]!
# 2024-03-28 12:24:32,217 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/30.ckpt.
# 2024-03-28 12:24:32,219 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:24:32,318 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:24:32,318 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:24:32,318 - INFO - joeynmt.training - 	Hypothesis: s
# 2024-03-28 12:24:32,477 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:24:32,554 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:24:32,554 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:24:32,555 - INFO - joeynmt.training - 	Hypothesis: s
# 2024-03-28 12:24:32,707 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:24:32,784 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:24:32,784 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:24:32,785 - INFO - joeynmt.training - 	Hypothesis: s
# 2024-03-28 12:24:32,945 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:24:33,017 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:24:33,017 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:24:33,017 - INFO - joeynmt.training - 	Hypothesis: s
# 2024-03-28 12:24:34,415 - INFO - joeynmt.training - Epoch   1, Step:       35, Batch Loss:     6.402409, Batch Acc: 0.093566, Tokens per Sec:     3402, Lr: 0.000105
# 2024-03-28 12:24:35,872 - INFO - joeynmt.training - Epoch   1, Step:       40, Batch Loss:     6.249054, Batch Acc: 0.098639, Tokens per Sec:     2827, Lr: 0.000120
# 2024-03-28 12:24:37,187 - INFO - joeynmt.training - Epoch   1, Step:       45, Batch Loss:     6.154976, Batch Acc: 0.097470, Tokens per Sec:     3248, Lr: 0.000135
# 2024-03-28 12:24:38,230 - INFO - joeynmt.training - Epoch   1, Step:       50, Batch Loss:     6.008217, Batch Acc: 0.102200, Tokens per Sec:     4059, Lr: 0.000150
# 2024-03-28 12:24:39,254 - INFO - joeynmt.training - Epoch   1, Step:       55, Batch Loss:     5.905971, Batch Acc: 0.101582, Tokens per Sec:     3829, Lr: 0.000165
# 2024-03-28 12:24:40,283 - INFO - joeynmt.training - Epoch   1, Step:       60, Batch Loss:     5.814814, Batch Acc: 0.096063, Tokens per Sec:     4096, Lr: 0.000180
# 2024-03-28 12:24:40,284 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=102
# 2024-03-28 12:24:40,285 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [00:04<00:00, 327.11it/s]
# 2024-03-28 12:24:44,749 - INFO - joeynmt.prediction - Generation took 4.4637[sec].
# 2024-03-28 12:24:44,896 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:24:44,896 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.00, loss:   5.74, ppl: 310.91, acc:   0.09, 0.0565[sec]
# 2024-03-28 12:24:44,897 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:24:44,975 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:24:44,976 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:24:44,976 - INFO - joeynmt.training - 	Hypothesis: s
# 2024-03-28 12:24:45,129 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:24:45,206 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:24:45,206 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:24:45,206 - INFO - joeynmt.training - 	Hypothesis: s
# 2024-03-28 12:24:45,372 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:24:45,454 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:24:45,454 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:24:45,454 - INFO - joeynmt.training - 	Hypothesis: s
# 2024-03-28 12:24:45,617 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:24:45,696 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:24:45,697 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:24:45,697 - INFO - joeynmt.training - 	Hypothesis: s
# 2024-03-28 12:24:47,201 - INFO - joeynmt.training - Epoch   1, Step:       65, Batch Loss:     5.608253, Batch Acc: 0.101379, Tokens per Sec:     3224, Lr: 0.000195
# 2024-03-28 12:24:48,827 - INFO - joeynmt.training - Epoch   1, Step:       70, Batch Loss:     5.517690, Batch Acc: 0.104206, Tokens per Sec:     2633, Lr: 0.000210
# 2024-03-28 12:24:50,114 - INFO - joeynmt.training - Epoch   1, Step:       75, Batch Loss:     5.372708, Batch Acc: 0.101456, Tokens per Sec:     3365, Lr: 0.000225
# 2024-03-28 12:24:51,229 - INFO - joeynmt.training - Epoch   1, Step:       80, Batch Loss:     5.340805, Batch Acc: 0.098804, Tokens per Sec:     3753, Lr: 0.000240
# 2024-03-28 12:24:52,363 - INFO - joeynmt.training - Epoch   1, Step:       85, Batch Loss:     5.332139, Batch Acc: 0.105050, Tokens per Sec:     3915, Lr: 0.000255
# 2024-03-28 12:24:53,455 - INFO - joeynmt.training - Epoch   1, Step:       90, Batch Loss:     5.310598, Batch Acc: 0.112437, Tokens per Sec:     3838, Lr: 0.000270
# 2024-03-28 12:24:53,456 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=132
# 2024-03-28 12:24:53,456 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [00:10<00:00, 137.96it/s]
# 2024-03-28 12:25:04,040 - INFO - joeynmt.prediction - Generation took 10.5833[sec].
# 2024-03-28 12:25:04,193 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:25:04,193 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.02, loss:   5.25, ppl: 191.42, acc:   0.11, 0.0583[sec]
# 2024-03-28 12:25:04,194 - INFO - joeynmt.training - Hooray! New best validation result [bleu]!
# 2024-03-28 12:25:04,542 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/90.ckpt.
# 2024-03-28 12:25:04,545 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:25:04,630 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:25:04,630 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:25:04,630 - INFO - joeynmt.training - 	Hypothesis: il
# 2024-03-28 12:25:04,788 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:25:04,866 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:25:04,867 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:25:04,867 - INFO - joeynmt.training - 	Hypothesis: il
# 2024-03-28 12:25:05,030 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:25:05,110 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:25:05,110 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:25:05,111 - INFO - joeynmt.training - 	Hypothesis: il
# 2024-03-28 12:25:05,258 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:25:05,333 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:25:05,333 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:25:05,333 - INFO - joeynmt.training - 	Hypothesis: il
# 2024-03-28 12:25:06,566 - INFO - joeynmt.training - Epoch   1, Step:       95, Batch Loss:     5.179179, Batch Acc: 0.121696, Tokens per Sec:     4040, Lr: 0.000285
# 2024-03-28 12:25:06,824 - INFO - joeynmt.training - Epoch   1, total training loss: 580.55, num. of seqs: 8065, num. of tokens: 80463, 23.6279[sec]
# 2024-03-28 12:25:06,825 - INFO - joeynmt.training - EPOCH 2
# 2024-03-28 12:25:07,677 - INFO - joeynmt.training - Epoch   2, Step:      100, Batch Loss:     5.184480, Batch Acc: 0.117070, Tokens per Sec:     4078, Lr: 0.000300
# 2024-03-28 12:25:08,704 - INFO - joeynmt.training - Epoch   2, Step:      105, Batch Loss:     5.292661, Batch Acc: 0.116380, Tokens per Sec:     4027, Lr: 0.000293
# 2024-03-28 12:25:09,774 - INFO - joeynmt.training - Epoch   2, Step:      110, Batch Loss:     5.162809, Batch Acc: 0.128007, Tokens per Sec:     4120, Lr: 0.000286
# 2024-03-28 12:25:10,871 - INFO - joeynmt.training - Epoch   2, Step:      115, Batch Loss:     5.194316, Batch Acc: 0.130072, Tokens per Sec:     4049, Lr: 0.000280
# 2024-03-28 12:25:11,961 - INFO - joeynmt.training - Epoch   2, Step:      120, Batch Loss:     5.021163, Batch Acc: 0.128525, Tokens per Sec:     3971, Lr: 0.000274
# 2024-03-28 12:25:11,962 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=162
# 2024-03-28 12:25:11,962 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [01:11<00:00, 20.36it/s]
# 2024-03-28 12:26:23,686 - INFO - joeynmt.prediction - Generation took 71.7227[sec].
# 2024-03-28 12:26:23,865 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:26:23,866 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.00, loss:   5.13, ppl: 169.59, acc:   0.12, 0.0573[sec]
# 2024-03-28 12:26:23,867 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:26:23,940 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:26:23,940 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:26:23,940 - INFO - joeynmt.training - 	Hypothesis: il’’’’’’’’’’’’’’’’’’’
# 2024-03-28 12:26:24,090 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:26:24,164 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:26:24,164 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:26:24,164 - INFO - joeynmt.training - 	Hypothesis: il’’’’’’’’’’’’’’’’’
# 2024-03-28 12:26:24,326 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:26:24,402 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:26:24,403 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:26:24,403 - INFO - joeynmt.training - 	Hypothesis: il’’’’’’’’’’’’’’’’’’
# 2024-03-28 12:26:24,552 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:26:24,630 - INFO - joeynmt.training - 	Source:     n ma daraka dun ban
# 2024-03-28 12:26:24,630 - INFO - joeynmt.training - 	Reference:  je n’ai pas encore déjeuné
# 2024-03-28 12:26:24,630 - INFO - joeynmt.training - 	Hypothesis: il’’’’’’’’’’’’’’’’’’’’
# 2024-03-28 12:26:25,963 - INFO - joeynmt.training - Epoch   2, Step:      125, Batch Loss:     5.210739, Batch Acc: 0.130424, Tokens per Sec:     3385, Lr: 0.000268
# 2024-03-28 12:26:27,103 - INFO - joeynmt.training - Epoch   2, Step:      130, Batch Loss:     4.987422, Batch Acc: 0.132513, Tokens per Sec:     3637, Lr: 0.000263
# 2024-03-28 12:26:28,385 - INFO - joeynmt.training - Epoch   2, Step:      135, Batch Loss:     5.049281, Batch Acc: 0.126629, Tokens per Sec:     3353, Lr: 0.000258
# 2024-03-28 12:26:30,026 - INFO - joeynmt.training - Epoch   2, Step:      140, Batch Loss:     5.042867, Batch Acc: 0.136576, Tokens per Sec:     2483, Lr: 0.000254
# 2024-03-28 12:26:31,438 - INFO - joeynmt.training - Epoch   2, Step:      145, Batch Loss:     5.051349, Batch Acc: 0.131882, Tokens per Sec:     2832, Lr: 0.000249
# 2024-03-28 12:26:32,561 - INFO - joeynmt.training - Epoch   2, Step:      150, Batch Loss:     4.935568, Batch Acc: 0.145116, Tokens per Sec:     3775, Lr: 0.000245
# 2024-03-28 12:26:32,562 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=192
# 2024-03-28 12:26:32,562 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [01:14<00:00, 19.57it/s]
# 2024-03-28 12:27:47,165 - INFO - joeynmt.prediction - Generation took 74.6016[sec].
# 2024-03-28 12:27:47,332 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:27:47,332 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.03, loss:   5.01, ppl: 149.54, acc:   0.13, 0.0593[sec]
# 2024-03-28 12:27:47,333 - INFO - joeynmt.training - Hooray! New best validation result [bleu]!
# 2024-03-28 12:27:47,696 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/150.ckpt.
# 2024-03-28 12:27:47,697 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:27:47,772 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:27:47,772 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:27:47,772 - INFO - joeynmt.training - 	Hypothesis: il’estestest
# 2024-03-28 12:27:47,924 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:27:48,002 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:27:48,003 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:27:48,003 - INFO - joeynmt.training - 	Hypothesis: il’estestest
# 2024-03-28 12:27:48,149 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:27:48,222 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:27:48,222 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:27:48,222 - INFO - joeynmt.training - 	Hypothesis: il’estestest
# 2024-03-28 12:27:48,370 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:27:48,445 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:27:48,445 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:27:48,445 - INFO - joeynmt.training - 	Hypothesis: il’estestest
# 2024-03-28 12:27:49,803 - INFO - joeynmt.training - Epoch   2, Step:      155, Batch Loss:     5.002584, Batch Acc: 0.140262, Tokens per Sec:     3625, Lr: 0.000241
# 2024-03-28 12:27:50,958 - INFO - joeynmt.training - Epoch   2, Step:      160, Batch Loss:     5.063284, Batch Acc: 0.141441, Tokens per Sec:     3584, Lr: 0.000237
# 2024-03-28 12:27:52,097 - INFO - joeynmt.training - Epoch   2, Step:      165, Batch Loss:     4.969552, Batch Acc: 0.154097, Tokens per Sec:     3773, Lr: 0.000234
# 2024-03-28 12:27:53,197 - INFO - joeynmt.training - Epoch   2, Step:      170, Batch Loss:     4.990413, Batch Acc: 0.142208, Tokens per Sec:     3807, Lr: 0.000230
# 2024-03-28 12:27:54,331 - INFO - joeynmt.training - Epoch   2, Step:      175, Batch Loss:     4.847930, Batch Acc: 0.142059, Tokens per Sec:     3788, Lr: 0.000227
# 2024-03-28 12:27:55,452 - INFO - joeynmt.training - Epoch   2, Step:      180, Batch Loss:     4.934126, Batch Acc: 0.149895, Tokens per Sec:     3826, Lr: 0.000224
# 2024-03-28 12:27:55,453 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=222
# 2024-03-28 12:27:55,453 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [01:12<00:00, 20.13it/s]
# 2024-03-28 12:29:07,982 - INFO - joeynmt.prediction - Generation took 72.5285[sec].
# 2024-03-28 12:29:08,218 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:29:08,218 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.03, loss:   4.88, ppl: 131.87, acc:   0.15, 0.1125[sec]
# 2024-03-28 12:29:08,219 - INFO - joeynmt.training - Hooray! New best validation result [bleu]!
# 2024-03-28 12:29:08,576 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/180.ckpt.
# 2024-03-28 12:29:08,578 - INFO - joeynmt.helpers - delete /content/models/dyu_fr/30.ckpt
# 2024-03-28 12:29:08,605 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:29:08,679 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:29:08,680 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:29:08,680 - INFO - joeynmt.training - 	Hypothesis: il est est est est est est est est est est est est est a
# 2024-03-28 12:29:08,826 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:29:08,905 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:29:08,906 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:29:08,906 - INFO - joeynmt.training - 	Hypothesis: il est est est est est est est est est est est la la laest
# 2024-03-28 12:29:09,067 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:29:09,151 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:29:09,151 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:29:09,151 - INFO - joeynmt.training - 	Hypothesis: il est est est est est est est est est est est est est est est est a
# 2024-03-28 12:29:09,310 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:29:09,393 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:29:09,393 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:29:09,394 - INFO - joeynmt.training - 	Hypothesis: il est est est est est est est est est est est est est est est a
# 2024-03-28 12:29:10,748 - INFO - joeynmt.training - Epoch   2, Step:      185, Batch Loss:     4.852148, Batch Acc: 0.157462, Tokens per Sec:     3539, Lr: 0.000221
# 2024-03-28 12:29:11,929 - INFO - joeynmt.training - Epoch   2, Step:      190, Batch Loss:     4.897743, Batch Acc: 0.161080, Tokens per Sec:     3513, Lr: 0.000218
# 2024-03-28 12:29:12,233 - INFO - joeynmt.training - Epoch   2, total training loss: 479.22, num. of seqs: 8065, num. of tokens: 80463, 22.4399[sec]
# 2024-03-28 12:29:12,233 - INFO - joeynmt.training - EPOCH 3
# 2024-03-28 12:29:13,140 - INFO - joeynmt.training - Epoch   3, Step:      195, Batch Loss:     4.821782, Batch Acc: 0.153798, Tokens per Sec:     3567, Lr: 0.000215
# 2024-03-28 12:29:14,761 - INFO - joeynmt.training - Epoch   3, Step:      200, Batch Loss:     4.759058, Batch Acc: 0.156456, Tokens per Sec:     2618, Lr: 0.000212
# 2024-03-28 12:29:16,302 - INFO - joeynmt.training - Epoch   3, Step:      205, Batch Loss:     4.871619, Batch Acc: 0.161306, Tokens per Sec:     2705, Lr: 0.000210
# 2024-03-28 12:29:17,428 - INFO - joeynmt.training - Epoch   3, Step:      210, Batch Loss:     4.819293, Batch Acc: 0.169238, Tokens per Sec:     3861, Lr: 0.000207
# 2024-03-28 12:29:17,429 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=252
# 2024-03-28 12:29:17,429 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [00:55<00:00, 26.31it/s]
# 2024-03-28 12:30:12,922 - INFO - joeynmt.prediction - Generation took 55.4919[sec].
# 2024-03-28 12:30:13,385 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:30:13,386 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.11, loss:   4.80, ppl: 121.23, acc:   0.16, 0.3526[sec]
# 2024-03-28 12:30:13,386 - INFO - joeynmt.training - Hooray! New best validation result [bleu]!
# 2024-03-28 12:30:13,737 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/210.ckpt.
# 2024-03-28 12:30:13,738 - INFO - joeynmt.helpers - delete /content/models/dyu_fr/90.ckpt
# 2024-03-28 12:30:13,764 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:30:13,845 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:30:13,845 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:30:13,845 - INFO - joeynmt.training - 	Hypothesis: il est est est est la a
# 2024-03-28 12:30:14,018 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:30:14,097 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:30:14,097 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:30:14,097 - INFO - joeynmt.training - 	Hypothesis: il est est est est la a
# 2024-03-28 12:30:14,251 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:30:14,326 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:30:14,326 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:30:14,326 - INFO - joeynmt.training - 	Hypothesis: il est est est est la a
# 2024-03-28 12:30:14,483 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:30:14,557 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:30:14,557 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:30:14,557 - INFO - joeynmt.training - 	Hypothesis: il est est est est la a
# 2024-03-28 12:30:15,933 - INFO - joeynmt.training - Epoch   3, Step:      215, Batch Loss:     4.767016, Batch Acc: 0.164838, Tokens per Sec:     3425, Lr: 0.000205
# 2024-03-28 12:30:17,124 - INFO - joeynmt.training - Epoch   3, Step:      220, Batch Loss:     4.746444, Batch Acc: 0.177661, Tokens per Sec:     3529, Lr: 0.000202
# 2024-03-28 12:30:18,382 - INFO - joeynmt.training - Epoch   3, Step:      225, Batch Loss:     4.788541, Batch Acc: 0.161501, Tokens per Sec:     3284, Lr: 0.000200
# 2024-03-28 12:30:19,978 - INFO - joeynmt.training - Epoch   3, Step:      230, Batch Loss:     4.760133, Batch Acc: 0.173893, Tokens per Sec:     2747, Lr: 0.000198
# 2024-03-28 12:30:21,473 - INFO - joeynmt.training - Epoch   3, Step:      235, Batch Loss:     4.739156, Batch Acc: 0.170870, Tokens per Sec:     2841, Lr: 0.000196
# 2024-03-28 12:30:22,602 - INFO - joeynmt.training - Epoch   3, Step:      240, Batch Loss:     4.642563, Batch Acc: 0.179888, Tokens per Sec:     3631, Lr: 0.000194
# 2024-03-28 12:30:22,602 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=282
# 2024-03-28 12:30:22,603 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [00:27<00:00, 53.32it/s]
# 2024-03-28 12:30:49,985 - INFO - joeynmt.prediction - Generation took 27.3813[sec].
# 2024-03-28 12:30:50,190 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:30:50,190 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.22, loss:   4.73, ppl: 113.41, acc:   0.17, 0.0884[sec]
# 2024-03-28 12:30:50,191 - INFO - joeynmt.training - Hooray! New best validation result [bleu]!
# 2024-03-28 12:30:50,534 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/240.ckpt.
# 2024-03-28 12:30:50,535 - INFO - joeynmt.helpers - delete /content/models/dyu_fr/150.ckpt
# 2024-03-28 12:30:50,564 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:30:50,645 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:30:50,645 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:30:50,645 - INFO - joeynmt.training - 	Hypothesis: je ne ne vous pas
# 2024-03-28 12:30:50,806 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:30:50,886 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:30:50,886 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:30:50,886 - INFO - joeynmt.training - 	Hypothesis: il est est la la la la ’est
# 2024-03-28 12:30:51,047 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:30:51,127 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:30:51,128 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:30:51,128 - INFO - joeynmt.training - 	Hypothesis: il est est la la la la ’est
# 2024-03-28 12:30:51,277 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:30:51,351 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:30:51,351 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:30:51,351 - INFO - joeynmt.training - 	Hypothesis: il est est la la la la ’est
# 2024-03-28 12:30:52,616 - INFO - joeynmt.training - Epoch   3, Step:      245, Batch Loss:     4.772581, Batch Acc: 0.174045, Tokens per Sec:     3830, Lr: 0.000192
# 2024-03-28 12:30:53,733 - INFO - joeynmt.training - Epoch   3, Step:      250, Batch Loss:     4.776049, Batch Acc: 0.170755, Tokens per Sec:     3688, Lr: 0.000190
# 2024-03-28 12:30:54,852 - INFO - joeynmt.training - Epoch   3, Step:      255, Batch Loss:     4.650821, Batch Acc: 0.178633, Tokens per Sec:     3625, Lr: 0.000188
# 2024-03-28 12:30:56,007 - INFO - joeynmt.training - Epoch   3, Step:      260, Batch Loss:     4.851122, Batch Acc: 0.174722, Tokens per Sec:     3818, Lr: 0.000186
# 2024-03-28 12:30:57,386 - INFO - joeynmt.training - Epoch   3, Step:      265, Batch Loss:     4.755864, Batch Acc: 0.174708, Tokens per Sec:     2857, Lr: 0.000184
# 2024-03-28 12:30:59,028 - INFO - joeynmt.training - Epoch   3, Step:      270, Batch Loss:     4.464914, Batch Acc: 0.181904, Tokens per Sec:     2594, Lr: 0.000183
# 2024-03-28 12:30:59,029 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=312
# 2024-03-28 12:30:59,029 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [00:37<00:00, 39.09it/s]
# 2024-03-28 12:31:36,380 - INFO - joeynmt.prediction - Generation took 37.3493[sec].
# 2024-03-28 12:31:36,722 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:31:36,722 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.31, loss:   4.68, ppl: 107.50, acc:   0.17, 0.1634[sec]
# 2024-03-28 12:31:36,723 - INFO - joeynmt.training - Hooray! New best validation result [bleu]!
# 2024-03-28 12:31:37,226 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/270.ckpt.
# 2024-03-28 12:31:37,228 - INFO - joeynmt.helpers - delete /content/models/dyu_fr/180.ckpt
# 2024-03-28 12:31:37,273 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:31:37,417 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:31:37,417 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:31:37,418 - INFO - joeynmt.training - 	Hypothesis: je suis sûr que vous
# 2024-03-28 12:31:37,698 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:31:37,782 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:31:37,782 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:31:37,782 - INFO - joeynmt.training - 	Hypothesis: il est est la la la la la a
# 2024-03-28 12:31:37,931 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:31:38,008 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:31:38,008 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:31:38,009 - INFO - joeynmt.training - 	Hypothesis: il est est la la la la la était
# 2024-03-28 12:31:38,156 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:31:38,231 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:31:38,232 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:31:38,232 - INFO - joeynmt.training - 	Hypothesis: il est est la la la la la était
# 2024-03-28 12:31:39,586 - INFO - joeynmt.training - Epoch   3, Step:      275, Batch Loss:     4.686357, Batch Acc: 0.182872, Tokens per Sec:     3299, Lr: 0.000181
# 2024-03-28 12:31:40,722 - INFO - joeynmt.training - Epoch   3, Step:      280, Batch Loss:     4.525064, Batch Acc: 0.177151, Tokens per Sec:     3654, Lr: 0.000179
# 2024-03-28 12:31:41,954 - INFO - joeynmt.training - Epoch   3, Step:      285, Batch Loss:     4.695869, Batch Acc: 0.168392, Tokens per Sec:     3529, Lr: 0.000178
# 2024-03-28 12:31:42,477 - INFO - joeynmt.training - Epoch   3, total training loss: 451.60, num. of seqs: 8065, num. of tokens: 80463, 24.6933[sec]
# 2024-03-28 12:31:42,477 - INFO - joeynmt.training - EPOCH 4
# 2024-03-28 12:31:43,234 - INFO - joeynmt.training - Epoch   4, Step:      290, Batch Loss:     4.690674, Batch Acc: 0.176244, Tokens per Sec:     3439, Lr: 0.000176
# 2024-03-28 12:31:44,448 - INFO - joeynmt.training - Epoch   4, Step:      295, Batch Loss:     4.542228, Batch Acc: 0.183888, Tokens per Sec:     3692, Lr: 0.000175
# 2024-03-28 12:31:45,680 - INFO - joeynmt.training - Epoch   4, Step:      300, Batch Loss:     4.415969, Batch Acc: 0.189703, Tokens per Sec:     3503, Lr: 0.000173
# 2024-03-28 12:31:45,681 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=342
# 2024-03-28 12:31:45,681 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [00:31<00:00, 46.54it/s]
# 2024-03-28 12:32:17,050 - INFO - joeynmt.prediction - Generation took 31.3681[sec].
# 2024-03-28 12:32:17,240 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:32:17,240 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.26, loss:   4.60, ppl:  99.98, acc:   0.18, 0.0877[sec]
# 2024-03-28 12:32:17,574 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/300.ckpt.
# 2024-03-28 12:32:17,575 - INFO - joeynmt.helpers - delete /content/models/dyu_fr/210.ckpt
# 2024-03-28 12:32:17,612 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:32:17,716 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:32:17,716 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:32:17,716 - INFO - joeynmt.training - 	Hypothesis: je ne vous pas pas
# 2024-03-28 12:32:17,868 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:32:17,941 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:32:17,941 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:32:17,941 - INFO - joeynmt.training - 	Hypothesis: il est la la la la la était
# 2024-03-28 12:32:18,091 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:32:18,168 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:32:18,168 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:32:18,168 - INFO - joeynmt.training - 	Hypothesis: il est la la la la la était
# 2024-03-28 12:32:18,330 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:32:18,407 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:32:18,407 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:32:18,407 - INFO - joeynmt.training - 	Hypothesis: c’est pas pas
# 2024-03-28 12:32:19,735 - INFO - joeynmt.training - Epoch   4, Step:      305, Batch Loss:     4.604432, Batch Acc: 0.186748, Tokens per Sec:     3651, Lr: 0.000172
# 2024-03-28 12:32:20,850 - INFO - joeynmt.training - Epoch   4, Step:      310, Batch Loss:     4.492152, Batch Acc: 0.182218, Tokens per Sec:     3875, Lr: 0.000170
# 2024-03-28 12:32:21,982 - INFO - joeynmt.training - Epoch   4, Step:      315, Batch Loss:     4.403422, Batch Acc: 0.196741, Tokens per Sec:     3744, Lr: 0.000169
# 2024-03-28 12:32:23,119 - INFO - joeynmt.training - Epoch   4, Step:      320, Batch Loss:     4.408264, Batch Acc: 0.196125, Tokens per Sec:     3678, Lr: 0.000168
# 2024-03-28 12:32:24,253 - INFO - joeynmt.training - Epoch   4, Step:      325, Batch Loss:     4.487048, Batch Acc: 0.190131, Tokens per Sec:     3773, Lr: 0.000166
# 2024-03-28 12:32:25,418 - INFO - joeynmt.training - Epoch   4, Step:      330, Batch Loss:     4.347027, Batch Acc: 0.203630, Tokens per Sec:     3693, Lr: 0.000165
# 2024-03-28 12:32:25,419 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=372
# 2024-03-28 12:32:25,419 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# ...
# 2024-03-28 12:34:41,368 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=462
# 2024-03-28 12:34:41,369 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [00:36<00:00, 39.58it/s]
# 2024-03-28 12:35:18,253 - INFO - joeynmt.prediction - Generation took 36.8831[sec].
# 2024-03-28 12:35:18,458 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:35:18,458 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.48, loss:   4.40, ppl:  81.55, acc:   0.19, 0.1020[sec]
# 2024-03-28 12:35:18,805 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/420.ckpt.
# 2024-03-28 12:35:18,806 - INFO - joeynmt.helpers - delete /content/models/dyu_fr/360.ckpt
# 2024-03-28 12:35:18,834 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:35:18,914 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:35:18,915 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:35:18,915 - INFO - joeynmt.training - 	Hypothesis: tu es sûr qu’est pas
# 2024-03-28 12:35:19,084 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:35:19,169 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:35:19,169 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:35:19,169 - INFO - joeynmt.training - 	Hypothesis: rue de la la la était
# 2024-03-28 12:35:19,328 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:35:19,399 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:35:19,399 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:35:19,399 - INFO - joeynmt.training - 	Hypothesis: le était de la la plus
# 2024-03-28 12:35:19,547 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:35:19,620 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:35:19,621 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:35:19,621 - INFO - joeynmt.training - 	Hypothesis: le était de la plus
# 2024-03-28 12:35:20,968 - INFO - joeynmt.training - Epoch   5, Step:      425, Batch Loss:     4.241402, Batch Acc: 0.215118, Tokens per Sec:     3497, Lr: 0.000146
# 2024-03-28 12:35:22,162 - INFO - joeynmt.training - Epoch   5, Step:      430, Batch Loss:     4.201494, Batch Acc: 0.224374, Tokens per Sec:     3549, Lr: 0.000145
# 2024-03-28 12:35:23,327 - INFO - joeynmt.training - Epoch   5, Step:      435, Batch Loss:     4.142074, Batch Acc: 0.208651, Tokens per Sec:     3831, Lr: 0.000144
# 2024-03-28 12:35:24,451 - INFO - joeynmt.training - Epoch   5, Step:      440, Batch Loss:     4.308553, Batch Acc: 0.215841, Tokens per Sec:     3844, Lr: 0.000143
# 2024-03-28 12:35:25,954 - INFO - joeynmt.training - Epoch   5, Step:      445, Batch Loss:     4.162453, Batch Acc: 0.206274, Tokens per Sec:     2950, Lr: 0.000142
# 2024-03-28 12:35:27,598 - INFO - joeynmt.training - Epoch   5, Step:      450, Batch Loss:     4.255886, Batch Acc: 0.210194, Tokens per Sec:     2603, Lr: 0.000141
# 2024-03-28 12:35:27,599 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=492
# 2024-03-28 12:35:27,599 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [00:43<00:00, 33.38it/s]
# 2024-03-28 12:36:11,338 - INFO - joeynmt.prediction - Generation took 43.7381[sec].
# 2024-03-28 12:36:11,569 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:36:11,569 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.60, loss:   4.37, ppl:  78.79, acc:   0.20, 0.1203[sec]
# 2024-03-28 12:36:11,570 - INFO - joeynmt.training - Hooray! New best validation result [bleu]!
# 2024-03-28 12:36:11,943 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/450.ckpt.
# 2024-03-28 12:36:11,944 - INFO - joeynmt.helpers - delete /content/models/dyu_fr/420.ckpt
# 2024-03-28 12:36:11,970 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:36:12,054 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:36:12,054 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:36:12,054 - INFO - joeynmt.training - 	Hypothesis: tu es sûr que tu
# 2024-03-28 12:36:12,222 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:36:12,305 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:36:12,305 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:36:12,305 - INFO - joeynmt.training - 	Hypothesis: rue de la la la mille
# 2024-03-28 12:36:12,460 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:36:12,541 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:36:12,542 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:36:12,542 - INFO - joeynmt.training - 	Hypothesis: le temps est la temps
# 2024-03-28 12:36:12,700 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:36:12,775 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:36:12,776 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:36:12,776 - INFO - joeynmt.training - 	Hypothesis: le cette était un cette était
# 2024-03-28 12:36:14,163 - INFO - joeynmt.training - Epoch   5, Step:      455, Batch Loss:     4.312025, Batch Acc: 0.214404, Tokens per Sec:     3491, Lr: 0.000141
# 2024-03-28 12:36:15,312 - INFO - joeynmt.training - Epoch   5, Step:      460, Batch Loss:     4.512787, Batch Acc: 0.210727, Tokens per Sec:     3653, Lr: 0.000140
# 2024-03-28 12:36:16,667 - INFO - joeynmt.training - Epoch   5, Step:      465, Batch Loss:     4.192854, Batch Acc: 0.208083, Tokens per Sec:     3070, Lr: 0.000139
# 2024-03-28 12:36:18,307 - INFO - joeynmt.training - Epoch   5, Step:      470, Batch Loss:     4.259021, Batch Acc: 0.227704, Tokens per Sec:     2571, Lr: 0.000138
# 2024-03-28 12:36:19,597 - INFO - joeynmt.training - Epoch   5, Step:      475, Batch Loss:     4.325287, Batch Acc: 0.210715, Tokens per Sec:     3246, Lr: 0.000138
# 2024-03-28 12:36:19,941 - INFO - joeynmt.training - Epoch   5, total training loss: 406.84, num. of seqs: 8065, num. of tokens: 80463, 24.7795[sec]
# 2024-03-28 12:36:19,942 - INFO - joeynmt.training - EPOCH 6
# 2024-03-28 12:36:20,812 - INFO - joeynmt.training - Epoch   6, Step:      480, Batch Loss:     4.271513, Batch Acc: 0.216053, Tokens per Sec:     4003, Lr: 0.000137
# 2024-03-28 12:36:20,813 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=522
# 2024-03-28 12:36:20,813 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [00:37<00:00, 39.35it/s]
# 2024-03-28 12:36:57,913 - INFO - joeynmt.prediction - Generation took 37.0985[sec].
# 2024-03-28 12:36:58,120 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:36:58,120 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.75, loss:   4.34, ppl:  76.47, acc:   0.20, 0.0958[sec]
# 2024-03-28 12:36:58,120 - INFO - joeynmt.training - Hooray! New best validation result [bleu]!
# 2024-03-28 12:36:58,502 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/480.ckpt.
# 2024-03-28 12:36:58,503 - INFO - joeynmt.helpers - delete /content/models/dyu_fr/390.ckpt
# 2024-03-28 12:36:58,530 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:36:58,607 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:36:58,607 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:36:58,608 - INFO - joeynmt.training - 	Hypothesis: tu es sûr que tu
# 2024-03-28 12:36:58,761 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:36:58,836 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:36:58,836 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:36:58,836 - INFO - joeynmt.training - 	Hypothesis: c’est ce que vous
# 2024-03-28 12:36:58,981 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:36:59,069 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:36:59,069 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:36:59,069 - INFO - joeynmt.training - 	Hypothesis: c’est un a pas
# 2024-03-28 12:36:59,221 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:36:59,295 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:36:59,295 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:36:59,295 - INFO - joeynmt.training - 	Hypothesis: c’est un était
# 2024-03-28 12:37:00,682 - INFO - joeynmt.training - Epoch   6, Step:      485, Batch Loss:     4.058496, Batch Acc: 0.226075, Tokens per Sec:     3417, Lr: 0.000136
# 2024-03-28 12:37:01,853 - INFO - joeynmt.training - Epoch   6, Step:      490, Batch Loss:     4.085818, Batch Acc: 0.222222, Tokens per Sec:     3645, Lr: 0.000136
# 2024-03-28 12:37:02,981 - INFO - joeynmt.training - Epoch   6, Step:      495, Batch Loss:     4.058011, Batch Acc: 0.224929, Tokens per Sec:     3752, Lr: 0.000135
# 2024-03-28 12:37:04,151 - INFO - joeynmt.training - Epoch   6, Step:      500, Batch Loss:     4.239876, Batch Acc: 0.228029, Tokens per Sec:     3599, Lr: 0.000134
# 2024-03-28 12:37:05,267 - INFO - joeynmt.training - Epoch   6, Step:      505, Batch Loss:     4.120848, Batch Acc: 0.224727, Tokens per Sec:     3779, Lr: 0.000133
# 2024-03-28 12:37:06,377 - INFO - joeynmt.training - Epoch   6, Step:      510, Batch Loss:     4.192809, Batch Acc: 0.238913, Tokens per Sec:     3781, Lr: 0.000133
# 2024-03-28 12:37:06,378 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=552
# 2024-03-28 12:37:06,378 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [01:01<00:00, 23.81it/s]
# 2024-03-28 12:38:07,690 - INFO - joeynmt.prediction - Generation took 61.3111[sec].
# 2024-03-28 12:38:07,908 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:38:07,908 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.61, loss:   4.30, ppl:  73.79, acc:   0.20, 0.1093[sec]
# 2024-03-28 12:38:08,263 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/510.ckpt.
# 2024-03-28 12:38:08,265 - INFO - joeynmt.helpers - delete /content/models/dyu_fr/330.ckpt
# 2024-03-28 12:38:08,301 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:38:08,382 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:38:08,383 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:38:08,383 - INFO - joeynmt.training - 	Hypothesis: tu es sûr que tu tu
# 2024-03-28 12:38:08,551 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:38:08,630 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:38:08,630 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:38:08,631 - INFO - joeynmt.training - 	Hypothesis: c’est un était un était
# 2024-03-28 12:38:08,786 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:38:08,863 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:38:08,863 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:38:08,863 - INFO - joeynmt.training - 	Hypothesis: le temps est la plus
# 2024-03-28 12:38:09,022 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:38:09,099 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:38:09,100 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:38:09,100 - INFO - joeynmt.training - 	Hypothesis: c’est un était un
# 2024-03-28 12:38:10,477 - INFO - joeynmt.training - Epoch   6, Step:      515, Batch Loss:     4.178405, Batch Acc: 0.223761, Tokens per Sec:     3365, Lr: 0.000132
# 2024-03-28 12:38:11,972 - INFO - joeynmt.training - Epoch   6, Step:      520, Batch Loss:     4.279901, Batch Acc: 0.226083, Tokens per Sec:     2734, Lr: 0.000132
# 2024-03-28 12:38:13,755 - INFO - joeynmt.training - Epoch   6, Step:      525, Batch Loss:     4.065808, Batch Acc: 0.216587, Tokens per Sec:     2456, Lr: 0.000131
# 2024-03-28 12:38:14,888 - INFO - joeynmt.training - Epoch   6, Step:      530, Batch Loss:     4.140155, Batch Acc: 0.226393, Tokens per Sec:     3834, Lr: 0.000130
# 2024-03-28 12:38:16,013 - INFO - joeynmt.training - Epoch   6, Step:      535, Batch Loss:     4.183528, Batch Acc: 0.226057, Tokens per Sec:     3893, Lr: 0.000130
# 2024-03-28 12:38:17,156 - INFO - joeynmt.training - Epoch   6, Step:      540, Batch Loss:     4.186241, Batch Acc: 0.233754, Tokens per Sec:     3744, Lr: 0.000129
# 2024-03-28 12:38:17,157 - INFO - joeynmt.datasets - Sample random subset from validation data: n=1460, seed=582
# 2024-03-28 12:38:17,157 - INFO - joeynmt.prediction - Predicting 1460 example(s)... (Greedy decoding with min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# Predicting...: 100% 1460/1460 [00:40<00:00, 35.82it/s]
# 2024-03-28 12:38:57,915 - INFO - joeynmt.prediction - Generation took 40.7570[sec].
# 2024-03-28 12:38:58,115 - INFO - joeynmt.metrics - nrefs:1|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.1
# 2024-03-28 12:38:58,116 - INFO - joeynmt.prediction - Evaluation result (greedy): bleu:   0.29, loss:   4.27, ppl:  71.85, acc:   0.20, 0.0991[sec]
# 2024-03-28 12:38:58,117 - INFO - joeynmt.training - Example #0
# 2024-03-28 12:38:58,482 - INFO - joeynmt.training - 	Source:     i tɔgɔ bi cogodɔ
# 2024-03-28 12:38:58,483 - INFO - joeynmt.training - 	Reference:  tu portes un nom de fantaisie
# 2024-03-28 12:38:58,483 - INFO - joeynmt.training - 	Hypothesis: tu es sûr qu’a
# 2024-03-28 12:38:58,631 - INFO - joeynmt.training - Example #1
# 2024-03-28 12:38:58,703 - INFO - joeynmt.training - 	Source:     puɛn saba fɔlɔ
# 2024-03-28 12:38:58,704 - INFO - joeynmt.training - 	Reference:  trois points d’avance
# 2024-03-28 12:38:58,704 - INFO - joeynmt.training - 	Hypothesis: rue de la numéro cent
# 2024-03-28 12:38:58,865 - INFO - joeynmt.training - Example #2
# 2024-03-28 12:38:58,938 - INFO - joeynmt.training - 	Source:     tile bena
# 2024-03-28 12:38:58,939 - INFO - joeynmt.training - 	Reference:  le soleil s’est couché
# 2024-03-28 12:38:58,939 - INFO - joeynmt.training - 	Hypothesis: les deux deux deux deux deux
# 2024-03-28 12:38:59,096 - INFO - joeynmt.training - Example #3
# 2024-03-28 12:38:59,173 - INFO - joeynmt.training - 	Source:     cogoya kelen
# 2024-03-28 12:38:59,173 - INFO - joeynmt.training - 	Reference:  mêmes mouvements
# 2024-03-28 12:38:59,173 - INFO - joeynmt.training - 	Hypothesis: une petites de la plus
# 2024-03-28 12:39:00,572 - INFO - joeynmt.training - Epoch   6, Step:      545, Batch Loss:     4.050585, Batch Acc: 0.222379, Tokens per Sec:     3421, Lr: 0.000129
# 2024-03-28 12:39:01,732 - INFO - joeynmt.training - Epoch   6, Step:      550, Batch Loss:     4.142549, Batch Acc: 0.229560, Tokens per Sec:     3567, Lr: 0.000128
# 2024-03-28 12:39:01,732 - INFO - joeynmt.training - Training ended since maximum num. of updates 550 was reached.
# 2024-03-28 12:39:01,732 - INFO - joeynmt.training - Best validation result (greedy) at step      480:   0.75 bleu.
# 2024-03-28 12:39:02,114 - INFO - joeynmt.training - Checkpoint saved in /content/models/dyu_fr/550.ckpt.
# 2024-03-28 12:39:02,115 - INFO - joeynmt.training - Skipping test after training.

# %%
# Add the best model info on config file
with (Path(model_dir) / "config.yaml").open('r') as f:
    config = f.read()
resume_config = config\
  .replace(f'#load_model: "{model_dir}/best.ckpt"',
           f'load_model: "{model_dir}/best.ckpt"')

resume_config = resume_config\
  .replace(f'model_file: "{data_dir}/sp.model"',
           f'model_file: "{model_dir}/sp.model"')

resume_config = resume_config\
  .replace(f'voc_file: "{data_dir}/vocab.txt"',
           f'voc_file: "{model_dir}/vocab.txt"')

with (Path(model_dir) / "config.yaml").open('w') as f:
    f.write(resume_config)

# %%
# !cp {data_dir}/vocab.txt  {model_dir}
# !cp -R {model_dir} /content/drive/MyDrive/mt-dyu-fr

# %% [markdown]
# ## Submit baseline model to Zindi

# %%
import pandas as pd

# %%
test = dataset["test"]
test
# Out:
# Dataset({
#     features: ['ID', 'translation'],
#     num_rows: 1393
# })

# %%
with open("source.txt", "w") as f:
     f.write("\n".join([sample["dyu"] for sample in test['translation']]))

# %%
# !python -m joeynmt translate {model_dir}/config.yaml < source.txt > translation.txt
# Out:
# 2024-03-28 12:39:09.172185: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-28 12:39:09.172243: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-28 12:39:09.173638: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-28 12:39:09.181272: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-28 12:39:10.320957: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-28 12:39:12,678 - INFO - root - Hello! This is Joey-NMT (version 2.3.0).
# 2024-03-28 12:39:12,719 - INFO - joeynmt.data - Building tokenizer...
# 2024-03-28 12:39:12,731 - INFO - joeynmt.tokenizers - dyu tokenizer: SentencePieceTokenizer(level=bpe, lowercase=False, normalize=False, filter_by_length=(-1, 100), pretokenizer=none, tokenizer=SentencePieceProcessor, nbest_size=5, alpha=0.0)
# 2024-03-28 12:39:12,732 - INFO - joeynmt.tokenizers - fr tokenizer: SentencePieceTokenizer(level=bpe, lowercase=False, normalize=False, filter_by_length=(-1, 100), pretokenizer=none, tokenizer=SentencePieceProcessor, nbest_size=5, alpha=0.0)
# 2024-03-28 12:39:12,732 - INFO - joeynmt.data - Building vocabulary...
# 2024-03-28 12:39:12,961 - INFO - joeynmt.data - Data loaded.
# 2024-03-28 12:39:12,961 - INFO - joeynmt.data - Train dataset: None
# 2024-03-28 12:39:12,962 - INFO - joeynmt.data - Valid dataset: None
# 2024-03-28 12:39:12,962 - INFO - joeynmt.data -  Test dataset: StreamDataset(split=test, len=0, src_lang="dyu", trg_lang="fr", has_trg=False, random_subset=-1, has_src_prompt=False, has_trg_prompt=False)
# 2024-03-28 12:39:12,962 - INFO - joeynmt.data - First 10 Src tokens: (0) <unk> (1) <pad> (2) <s> (3) </s> (4) ▁a (5) s (6) ▁ka (7) ' (8) a (9) ▁la
# 2024-03-28 12:39:12,962 - INFO - joeynmt.data - First 10 Trg tokens: (0) <unk> (1) <pad> (2) <s> (3) </s> (4) ▁a (5) s (6) ▁ka (7) ' (8) a (9) ▁la
# 2024-03-28 12:39:12,962 - INFO - joeynmt.data - Number of unique Src tokens (vocab_size): 4000
# 2024-03-28 12:39:12,963 - INFO - joeynmt.data - Number of unique Trg tokens (vocab_size): 4000
# 2024-03-28 12:39:12,963 - INFO - joeynmt.model - Building an encoder-decoder model...
# 2024-03-28 12:39:13,207 - INFO - joeynmt.model - Enc-dec model built.
# 2024-03-28 12:39:13,211 - INFO - joeynmt.model - Total params: 12084224
# 2024-03-28 12:39:13,212 - INFO - joeynmt.prediction - Loading model from /content/models/dyu_fr/best.ckpt
# 2024-03-28 12:39:13,809 - INFO - joeynmt.prediction - Model(
# 	encoder=TransformerEncoder(num_layers=6, num_heads=4, alpha=1.0, layer_norm="pre", activation=ReLU()),
# 	decoder=TransformerDecoder(num_layers=6, num_heads=8, alpha=1.0, layer_norm="pre", activation=ReLU()),
# 	src_embed=Embeddings(embedding_dim=256, vocab_size=4000),
# 	trg_embed=Embeddings(embedding_dim=256, vocab_size=4000),
# 	loss_function=XentLoss(criterion=KLDivLoss(), smoothing=0.1))
# 2024-03-28 12:39:13,811 - INFO - joeynmt.prediction - Ready to decode. (device: cuda, n_gpu: 1, use_ddp: False, fp16: False)
# 2024-03-28 12:39:13,828 - INFO - joeynmt.prediction - Predicting 1393 example(s)... (Beam search with beam_size=5, beam_alpha=1.0, n_best=1, min_output_length=1, max_output_length=100, return_prob='none', generate_unk=True, repetition_penalty=-1, no_repeat_ngram_size=-1)
# 2024-03-28 12:40:17,093 - INFO - joeynmt.prediction - Generation took 63.2635[sec].

# %%
with open("translation.txt") as f:
    sub = pd.DataFrame({
        "ID": test["ID"],
        "Target": f.read().strip().split("\n")}
    )

sub
# Out:
#                      ID                  Target
# 0     ID_17345911362699    tu es sûr qu'est pas
# 1     ID_173626847.3381     c’est ce qu’est pas
# 2     ID_17704632382547   je suis sûr qu’ai pas
# 3     ID_19793499384156          tu es sûr qu’a
# 4     ID_17802727385575     c’est ce qu’est pas
# ...                 ...                     ...
# 1388  ID_17319547625075  je suis sûr qu’est pas
# 1389  ID_19774885625614     c’est ce qu’est pas
# 1390  ID_17405744626334        qu’est vous vous
# 1391  ID_19074638626892    il n'est pas de l'as
# 1392  ID_19759971627433     c’est ce qu’est pas
#
# [1393 rows x 2 columns]

# %%
sub.to_csv("Submission.csv", index=False)
# !cp -R Submission.csv /content/drive/MyDrive/mt-dyu-fr

# %% [markdown]
# Your submission should get you a bleu score of around 16% on the leadboard. To improve your models please play around with the different parameters in the config file and don't forget to clean your data as much as possible.

# %% [markdown]
# Author : [Data354](https://data354.com/en/)
#
# Thanks to Julia & Co for making [JoeyNMT transformers](https://github.com/joeynmt/joeynmt) so simple to use.
